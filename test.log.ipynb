# %%
from ox_db.db.log import Log

log=Log("test")
# Out:
# /home/lokesh/.local/lib/python3.11/site-packages/sentence_transformers/cross_encoder/CrossEncoder.py:11: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm, trange
# /home/lokesh/.local/lib/python3.11/site-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(

# %%
log.set_doc("note")
# Out:
# 'note'

# %%
log.push("remember me : need to do code implementation for key lang conversation ")
log.push("remember me : gym time is morning from today  ")
log.push("remember me : base vector db arcchitecture is done  ")
log.push("remember me : need to do more research on deep learning  ")
# Out:
# ox-db: Logged data: 57ff1961-c316-45c6-bd92-cc066fc249b2 in note.index
# ox-db: Logged data: c515b679-57c6-4a56-9039-54583b804f41 in note.index
# ox-db: Logged data: 47b87008-204e-4fdb-b74a-f8b71894c872 in note.index
# ox-db: Logged data: 4f0e4bab-a2b0-49f5-940c-cffc7fb826c0 in note.index
# '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0'

# %%
log.doc_entry
# Out:
# 62

# %%
log.push("need to do : find efficient data store and retrive method  ")
log.push("need to do : i need to finesh deamon search asap  ")
log.push("need to do : need to sleep  ")
log.push("need to do : look out for bugs in code base and fix it   ")
# Out:
# ox-db: Logged data: 14bd8374-0916-429a-96ed-525147c0bb02 in note.index
# ox-db: Logged data: 899f5e8d-e08d-468f-8b3e-ebd51d3caa2d in note.index
# ox-db: Logged data: c16421c1-b4c2-4976-afe4-baf8522ea79a in note.index
# ox-db: Logged data: 28e2f6a2-0b6b-40b8-90cf-eb78ae756556 in note.index
# '28e2f6a2-0b6b-40b8-90cf-eb78ae756556'

# %%
log.push("Hi I'm OX-AI your AI personal database ")
log.push("I can store your documents with vector embaddings and retrive it based on vector search")
log.push("I'm currently under development")
log.push("looking forward to do more to increase your productivity!")
log.push("Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!")
# Out:
# ox-db: Logged data: de16266c-7496-4553-947a-a9f58cc578cd in note.index
# ox-db: Logged data: 5c25c24a-4b6c-4dc5-986e-f4abc58b8f97 in note.index
# ox-db: Logged data: 5a5cf91d-8cca-489b-8e73-2de8a85f7f42 in note.index
# ox-db: Logged data: 80c1f31d-d70e-49fa-b879-fdf9952edf9c in note.index
# ox-db: Logged data: 08f3268e-d81f-4f12-8c9a-776af4f9a789 in note.index
# '08f3268e-d81f-4f12-8c9a-776af4f9a789'

# %%
log.push("hi",key="time")
# Out:
# ox-db: Logged data: 91bfdb7f-7392-4237-b357-d723fa893908 in note.index
# '91bfdb7f-7392-4237-b357-d723fa893908'

# %%
log.pull()
# Out:
# [{'uid': '797d5299-734b-4dfc-852c-b01780ff12b8',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': 'ea9ce250-9ab7-4565-9fd1-8c00c9744802',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': '98cfb8f3-7d42-41ad-ae88-a1d5af03ff40',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '036a1cd9-90cb-4286-bb6c-bc4a21816ea8',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '1c3d0a2a-6c2b-4f55-891b-be6f4dae35bf',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '4c72cdb5-a625-4456-8494-0a7fa9540afb',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '081b1154-3537-450c-9453-b01e79751c58',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': '9f4a4a37-8791-468b-8c98-f155f1953648',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '9d06846d-270f-4c0c-b379-72e18a48fb5b',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '19abd193-860d-4da9-9f66-a2cb91747b45',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '8de92249-5e77-45b3-af7a-81f329af6038',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'd0e1f65c-3540-4268-807a-e361acfa81e5',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': 

#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#   'unit': {'data': 'hi', 'description': None}}]

# %%
log.search("hi ox-ai",3)
# Out:
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# [{'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '60d62e59-58ac-4eac-9694-ba157656c872',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}}]

# %%
log.gen_uid()
# Out:
# '94f4e3b4-ef19-4db2-b53e-5e11ab9ff31a'

# %%
log.push("need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel")
# Out:
# ox-db: Logged data: fc468332-3d1f-4185-a9b9-efd279068c66 in note.index
# 'fc468332-3d1f-4185-a9b9-efd279068c66'

# %%
# %%time
log.search("rag",2)
# Out:
# ox-db : {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel', 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# CPU times: user 260 ms, sys: 39.3 ms, total: 300 ms
# Wall time: 264 ms
# [{'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#   'unit': {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel',
#    'description': None}},
#  {'uid': '4c72e090-1501-42b6-ab10-7d6af8c110e7',
#   'unit': {'data': 'hi', 'description': None}}]

# %%
# %%time
_=log.pull()
# Out:
# CPU times: user 1.5 ms, sys: 502 µs, total: 2 ms
# Wall time: 1.73 ms

# %%
# %%time
log.pull()
# Out:
# CPU times: user 2.51 ms, sys: 0 ns, total: 2.51 ms
# Wall time: 2.19 ms
# [{'uid': '797d5299-734b-4dfc-852c-b01780ff12b8',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': 'ea9ce250-9ab7-4565-9fd1-8c00c9744802',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': '98cfb8f3-7d42-41ad-ae88-a1d5af03ff40',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '036a1cd9-90cb-4286-bb6c-bc4a21816ea8',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '1c3d0a2a-6c2b-4f55-891b-be6f4dae35bf',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '4c72cdb5-a625-4456-8494-0a7fa9540afb',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '081b1154-3537-450c-9453-b01e79751c58',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': '9f4a4a37-8791-468b-8c98-f155f1953648',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '9d06846d-270f-4c0c-b379-72e18a48fb5b',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '19abd193-860d-4da9-9f66-a2cb91747b45',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '8de92249-5e77-45b3-af7a-81f329af6038',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'd0e1f65c-3540-4268-807a-e361acfa81e5',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': 'c20037dc-1a45-4fad-946c-74b930ae8bce',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': 'cea73fbb-3b39-4f3d-a41e-b7196d9d32b4',
#   'unit': {'data': 'hi', 'description': None}},
#  {'uid': '3e6e21e5-6fbd-4317-9da5-1ae3db1800ff',
#   'unit': {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel',
#    'description': None}},
#  {'uid': 'd308825d-f525-4122-a88b-dcbcc11954df',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': '1f4054bd-2a20-45f3-8aac-c4444420a722',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': 'b142bba7-76ee-4be2-becd-741dc4dfb800',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '0b0e656b-9419-4e5d-bb02-975cd75d918e',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '9ad31dd7-419f-4f7d-b6f2-9a2073baaf9c',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '089cd944-af75-4281-a5f0-c9b6a77db3d6',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '42294d14-0799-4200-82e3-2cdb15b04056',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': 'a32d8199-d3f4-42ce-b7b6-de4ddb5b5f16',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '7cbea21b-94a4-4869-9c77-147e5e26b729',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': 'db25228f-822e-4cf8-bc29-4219bf2dc465',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '3ad2906d-fb7a-4b11-ad04-48733b6bb36e',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': 'I can store your documents with vector embaddings and retrive it based on vector search', 'description': None}
# ox-db : {'data': "I'm currently under development", 'description': None}
# ox-db : {'data': 'looking forward to do more to increase your productivity!', 'description': None}
# ox-db : {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!", 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# ox-db : {'data': 'remember me : need to do code implementation for key lang conversation ', 'description': None}
# ox-db : {'data': 'remember me : gym time is morning from today  ', 'description': None}
# ox-db : {'data': 'remember me : base vector db arcchitecture is done  ', 'description': None}
# ox-db : {'data': 'remember me : need to do more research on deep learning  ', 'description': None}
# ox-db : {'data': 'need to do : find efficient data store and retrive method  ', 'description': None}
# ox-db : {'data': 'need to do : i need to finesh deamon search asap  ', 'description': None}
# ox-db : {'data': 'need to do : need to sleep  ', 'description': None}
# ox-db : {'data': 'need to do : look out for bugs in code base and fix it   ', 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': 'I can store your documents with vector embaddings and retrive it based on vector search', 'description': None}
# ox-db : {'data': "I'm currently under development", 'description': None}
# ox-db : {'data': 'looking forward to do more to increase your productivity!', 'description': None}
# ox-db : {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!", 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# ox-db : {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel', 'description': None}
# [{'uid': 'f8a8f2a7-05d7-4fb0-a7cc-516fd374e822',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': 'b76614d4-8671-483d-b00f-250f3ae7a998',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': 'fffcd5ae-aa2d-4c88-9e81-cc057d2e6536',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '4cc2ad64-b290-49aa-8287-ffd4c215cf46',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': 'fd4d71fc-27be-418a-a7af-796be6987bf4',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '3c5d99d4-4aef-4819-a7fa-98220dc25652',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '6c92f379-19db-4e5d-9bdd-e080346e9dea',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': '78d9e175-9473-4ba0-b856-ace82fea4c71',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '7c047168-f27e-4a08-b709-ecd13b661306',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '71141ad1-988c-425c-80d4-c39ed4db0501',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'ab624e53-4c03-42a8-9cbe-2a0c7afcf9e5',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': '4cb1e098-dfd8-4753-a9fb-34f18ae1d742',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#   'unit': {'data': 'hi', 'description': None}},
#  {'uid': '57ff1961-c316-45c6-bd92-cc066fc249b2',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': 'c515b679-57c6-4a56-9039-54583b804f41',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': '47b87008-204e-4fdb-b74a-f8b71894c872',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '942a6864-d942-4933-99c4-1bb0295f49f9',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': 'e8c01e3a-c4ea-414e-8bf7-703ae5157714',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '8e638e9b-df13-4bdf-9e7d-2da6ed34a655',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': 'dbf119b9-8f7a-4f27-9891-7373825423e1',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#   'unit': {'data': 'hi', 'description': None}},
#  {'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#   'unit': {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel',
#    'description': None}}]

# %%
log.pull(date="30_06")
# Out:
# ox-db : {'data': 'remember me : need to do code implementation for key lang conversation ', 'description': None}
# ox-db : {'data': 'remember me : gym time is morning from today  ', 'description': None}
# ox-db : {'data': 'remember me : base vector db arcchitecture is done  ', 'description': None}
# ox-db : {'data': 'remember me : need to do more research on deep learning  ', 'description': None}
# ox-db : {'data': 'need to do : find efficient data store and retrive method  ', 'description': None}
# ox-db : {'data': 'need to do : i need to finesh deamon search asap  ', 'description': None}
# ox-db : {'data': 'need to do : need to sleep  ', 'description': None}
# ox-db : {'data': 'need to do : look out for bugs in code base and fix it   ', 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': 'I can store your documents with vector embaddings and retrive it based on vector search', 'description': None}
# ox-db : {'data': "I'm currently under development", 'description': None}
# ox-db : {'data': 'looking forward to do more to increase your productivity!', 'description': None}
# ox-db : {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!", 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# ox-db : {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel', 'description': None}
# ox-db : {'data': 'remember me : need to do code implementation for key lang conversation ', 'description': None}
# ox-db : {'data': 'remember me : gym time is morning from today  ', 'description': None}
# ox-db : {'data': 'remember me : base vector db arcchitecture is done  ', 'description': None}
# ox-db : {'data': 'remember me : need to do more research on deep learning  ', 'description': None}
# ox-db : {'data': 'need to do : find efficient data store and retrive method  ', 'description': None}
# ox-db : {'data': 'need to do : i need to finesh deamon search asap  ', 'description': None}
# ox-db : {'data': 'need to do : need to sleep  ', 'description': None}
# ox-db : {'data': 'need to do : look out for bugs in code base and fix it   ', 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': 'I can store your documents with vector embaddings and retrive it based on vector search', 'description': None}
# ox-db : {'data': "I'm currently under development", 'description': None}
# ox-db : {'data': 'looking forward to do more to increase your productivity!', 'description': None}
# ox-db : {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!", 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# ox-db : {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel', 'description': None}
# ox-db : {'data': 'remember me : need to do code implementation for key lang conversation ', 'description': None}
# ox-db : {'data': 'remember me : gym time is morning from today  ', 'description': None}
# ox-db : {'data': 'remember me : base vector db arcchitecture is done  ', 'description': None}
# ox-db : {'data': 'remember me : need to do more research on deep learning  ', 'description': None}
# ox-db : {'data': 'need to do : find efficient data store and retrive method  ', 'description': None}
# ox-db : {'data': 'need to do : i need to finesh deamon search asap  ', 'description': None}
# ox-db : {'data': 'need to do : need to sleep  ', 'description': None}
# ox-db : {'data': 'need to do : look out for bugs in code base and fix it   ', 'description': None}
# ox-db : {'data': "Hi I'm OX-AI your AI personal database ", 'description': None}
# ox-db : {'data': 'I can store your documents with vector embaddings and retrive it based on vector search', 'description': None}
# ox-db : {'data': "I'm currently under development", 'description': None}
# ox-db : {'data': 'looking forward to do more to increase your productivity!', 'description': None}
# ox-db : {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!", 'description': None}
# ox-db : {'data': 'hi', 'description': None}
# [{'uid': '797d5299-734b-4dfc-852c-b01780ff12b8',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': 'ea9ce250-9ab7-4565-9fd1-8c00c9744802',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': '98cfb8f3-7d42-41ad-ae88-a1d5af03ff40',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '036a1cd9-90cb-4286-bb6c-bc4a21816ea8',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '1c3d0a2a-6c2b-4f55-891b-be6f4dae35bf',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '4c72cdb5-a625-4456-8494-0a7fa9540afb',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '081b1154-3537-450c-9453-b01e79751c58',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': '9f4a4a37-8791-468b-8c98-f155f1953648',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '9d06846d-270f-4c0c-b379-72e18a48fb5b',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '19abd193-860d-4da9-9f66-a2cb91747b45',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '8de92249-5e77-45b3-af7a-81f329af6038',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': 'd0e1f65c-3540-4268-807a-e361acfa81e5',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': 'c20037dc-1a45-4fad-946c-74b930ae8bce',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': 'cea73fbb-3b39-4f3d-a41e-b7196d9d32b4',
#   'unit': {'data': 'hi', 'description': None}},
#  {'uid': '3e6e21e5-6fbd-4317-9da5-1ae3db1800ff',
#   'unit': {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel',
#    'description': None}},
#  {'uid': 'd308825d-f525-4122-a88b-dcbcc11954df',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': '1f4054bd-2a20-45f3-8aac-c4444420a722',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': 'b142bba7-76ee-4be2-becd-741dc4dfb800',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '0b0e656b-9419-4e5d-bb02-975cd75d918e',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': '9ad31dd7-419f-4f7d-b6f2-9a2073baaf9c',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': '089cd944-af75-4281-a5f0-c9b6a77db3d6',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '42294d14-0799-4200-82e3-2cdb15b04056',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': 'a32d8199-d3f4-42ce-b7b6-de4ddb5b5f16',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '7cbea21b-94a4-4869-9c77-147e5e26b729',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': 'db25228f-822e-4cf8-bc29-4219bf2dc465',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '3ad2906d-fb7a-4b11-ad04-48733b6bb36e',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': '36428d98-ceb3-4593-976d-f97eb8fcf290',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': 'dae932b6-b8a9-49a5-b403-8311b5d169f3',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': 'be844780-80d3-4733-9922-639c7a639d7d',
#   'unit': {'data': 'hi', 'description': None}},
#  {'uid': '0e6549ab-1b5b-4d07-9f93-1b4b73507df1',
#   'unit': {'data': 'need to : implement rag system that pulls data from the internet and chunk it and store as knowledge for easy retrivel',
#    'description': None}},
#  {'uid': 'a471f39b-c108-4b90-85af-52c9cc24e78f',
#   'unit': {'data': 'remember me : need to do code implementation for key lang conversation ',
#    'description': None}},
#  {'uid': '9b710b29-eafd-47d4-bc9f-5011cf44c7a6',
#   'unit': {'data': 'remember me : gym time is morning from today  ',
#    'description': None}},
#  {'uid': 'dac7b753-8351-4bf3-b7bf-e52b34623abe',
#   'unit': {'data': 'remember me : base vector db arcchitecture is done  ',
#    'description': None}},
#  {'uid': '80c6d409-9347-4d90-bb95-d432832abe37',
#   'unit': {'data': 'remember me : need to do more research on deep learning  ',
#    'description': None}},
#  {'uid': 'f96dd7e4-70bc-4e3d-91f1-8c7d1ca6b153',
#   'unit': {'data': 'need to do : find efficient data store and retrive method  ',
#    'description': None}},
#  {'uid': 'f935f45a-cfcc-4002-9c26-7b5f7260ae87',
#   'unit': {'data': 'need to do : i need to finesh deamon search asap  ',
#    'description': None}},
#  {'uid': '4abccd97-4eb2-4866-80e4-40a3d88987ab',
#   'unit': {'data': 'need to do : need to sleep  ', 'description': None}},
#  {'uid': 'ae49a91e-e850-4459-92d2-5056f2496729',
#   'unit': {'data': 'need to do : look out for bugs in code base and fix it   ',
#    'description': None}},
#  {'uid': '60d62e59-58ac-4eac-9694-ba157656c872',
#   'unit': {'data': "Hi I'm OX-AI your AI personal database ",
#    'description': None}},
#  {'uid': '441cbfca-23ad-429c-99f8-384948303f6c',
#   'unit': {'data': 'I can store your documents with vector embaddings and retrive it based on vector search',
#    'description': None}},
#  {'uid': '67608f03-543d-47ee-8fd5-b0a73b2a73f2',
#   'unit': {'data': "I'm currently under development", 'description': None}},
#  {'uid': '45c915a6-2bad-4138-97c5-4514691cc038',
#   'unit': {'data': 'looking forward to do more to increase your productivity!',
#    'description': None}},
#  {'uid': 'dc128673-4558-4d22-ab35-9e937b573a1f',
#   'unit': {'data': "Hi I'm your AI personal database and I can store your documents with vector embeddings and retrieve them based on vector search. I'm currently under development, looking forward to doing more to increase your productivity!",
#    'description': None}},
#  {'uid': '4c72e090-1501-42b6-ab10-7d6af8c110e7',
#   'unit': {'data': 'hi', 'description': None}}]

# %%
log.search_uid(key="time")
# Out:
# ['cea73fbb-3b39-4f3d-a41e-b7196d9d32b4',
#  'be844780-80d3-4733-9922-639c7a639d7d',
#  '4c72e090-1501-42b6-ab10-7d6af8c110e7',
#  '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#  '91bfdb7f-7392-4237-b357-d723fa893908']

# %%
uids = log.search_uid(time="12")

# %%
# %%time
log.pull(uid=uids,docfile=".index")
# Out:
# CPU times: user 0 ns, sys: 2.71 ms, total: 2.71 ms
# Wall time: 1.78 ms
# [{'uid': 'f8a8f2a7-05d7-4fb0-a7cc-516fd374e822',
#   'unit': {'uid': 'f8a8f2a7-05d7-4fb0-a7cc-516fd374e822',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:06_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'b76614d4-8671-483d-b00f-250f3ae7a998',
#   'unit': {'uid': 'b76614d4-8671-483d-b00f-250f3ae7a998',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fffcd5ae-aa2d-4c88-9e81-cc057d2e6536',
#   'unit': {'uid': 'fffcd5ae-aa2d-4c88-9e81-cc057d2e6536',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cc2ad64-b290-49aa-8287-ffd4c215cf46',
#   'unit': {'uid': '4cc2ad64-b290-49aa-8287-ffd4c215cf46',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fd4d71fc-27be-418a-a7af-796be6987bf4',
#   'unit': {'uid': 'fd4d71fc-27be-418a-a7af-796be6987bf4',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '3c5d99d4-4aef-4819-a7fa-98220dc25652',
#   'unit': {'uid': '3c5d99d4-4aef-4819-a7fa-98220dc25652',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '6c92f379-19db-4e5d-9bdd-e080346e9dea',
#   'unit': {'uid': '6c92f379-19db-4e5d-9bdd-e080346e9dea',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '78d9e175-9473-4ba0-b856-ace82fea4c71',
#   'unit': {'uid': '78d9e175-9473-4ba0-b856-ace82fea4c71',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#   'unit': {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '7c047168-f27e-4a08-b709-ecd13b661306',
#   'unit': {'uid': '7c047168-f27e-4a08-b709-ecd13b661306',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '71141ad1-988c-425c-80d4-c39ed4db0501',
#   'unit': {'uid': '71141ad1-988c-425c-80d4-c39ed4db0501',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'ab624e53-4c03-42a8-9cbe-2a0c7afcf9e5',
#   'unit': {'uid': 'ab624e53-4c03-42a8-9cbe-2a0c7afcf9e5',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cb1e098-dfd8-4753-a9fb-34f18ae1d742',
#   'unit': {'uid': '4cb1e098-dfd8-4753-a9fb-34f18ae1d742',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#   'unit': {'uid': '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#    'key': 'time',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '57ff1961-c316-45c6-bd92-cc066fc249b2',
#   'unit': {'uid': '57ff1961-c316-45c6-bd92-cc066fc249b2',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'c515b679-57c6-4a56-9039-54583b804f41',
#   'unit': {'uid': 'c515b679-57c6-4a56-9039-54583b804f41',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '47b87008-204e-4fdb-b74a-f8b71894c872',
#   'unit': {'uid': '47b87008-204e-4fdb-b74a-f8b71894c872',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0',
#   'unit': {'uid': '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '942a6864-d942-4933-99c4-1bb0295f49f9',
#   'unit': {'uid': '942a6864-d942-4933-99c4-1bb0295f49f9',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'e8c01e3a-c4ea-414e-8bf7-703ae5157714',
#   'unit': {'uid': 'e8c01e3a-c4ea-414e-8bf7-703ae5157714',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '8e638e9b-df13-4bdf-9e7d-2da6ed34a655',
#   'unit': {'uid': '8e638e9b-df13-4bdf-9e7d-2da6ed34a655',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'dbf119b9-8f7a-4f27-9891-7373825423e1',
#   'unit': {'uid': 'dbf119b9-8f7a-4f27-9891-7373825423e1',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#   'unit': {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#   'unit': {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#   'unit': {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#   'unit': {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#   'unit': {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#   'unit': {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#    'key': 'time',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#   'unit': {'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:03_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}}]

# %%
log.pull(time="12",docfile=".index")
# Out:
# [{'uid': 'f8a8f2a7-05d7-4fb0-a7cc-516fd374e822',
#   'unit': {'uid': 'f8a8f2a7-05d7-4fb0-a7cc-516fd374e822',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:06_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'b76614d4-8671-483d-b00f-250f3ae7a998',
#   'unit': {'uid': 'b76614d4-8671-483d-b00f-250f3ae7a998',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fffcd5ae-aa2d-4c88-9e81-cc057d2e6536',
#   'unit': {'uid': 'fffcd5ae-aa2d-4c88-9e81-cc057d2e6536',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cc2ad64-b290-49aa-8287-ffd4c215cf46',
#   'unit': {'uid': '4cc2ad64-b290-49aa-8287-ffd4c215cf46',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fd4d71fc-27be-418a-a7af-796be6987bf4',
#   'unit': {'uid': 'fd4d71fc-27be-418a-a7af-796be6987bf4',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '3c5d99d4-4aef-4819-a7fa-98220dc25652',
#   'unit': {'uid': '3c5d99d4-4aef-4819-a7fa-98220dc25652',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '6c92f379-19db-4e5d-9bdd-e080346e9dea',
#   'unit': {'uid': '6c92f379-19db-4e5d-9bdd-e080346e9dea',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '78d9e175-9473-4ba0-b856-ace82fea4c71',
#   'unit': {'uid': '78d9e175-9473-4ba0-b856-ace82fea4c71',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#   'unit': {'uid': 'b6ad3787-a311-4817-9b67-e482662df87a',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '7c047168-f27e-4a08-b709-ecd13b661306',
#   'unit': {'uid': '7c047168-f27e-4a08-b709-ecd13b661306',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '71141ad1-988c-425c-80d4-c39ed4db0501',
#   'unit': {'uid': '71141ad1-988c-425c-80d4-c39ed4db0501',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'ab624e53-4c03-42a8-9cbe-2a0c7afcf9e5',
#   'unit': {'uid': 'ab624e53-4c03-42a8-9cbe-2a0c7afcf9e5',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cb1e098-dfd8-4753-a9fb-34f18ae1d742',
#   'unit': {'uid': '4cb1e098-dfd8-4753-a9fb-34f18ae1d742',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#   'unit': {'uid': '34f71be2-e92a-4cad-a43e-e8372ecd9f02',
#    'key': 'time',
#    'doc': 'note',
#    'time': '12:01:07_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '57ff1961-c316-45c6-bd92-cc066fc249b2',
#   'unit': {'uid': '57ff1961-c316-45c6-bd92-cc066fc249b2',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'c515b679-57c6-4a56-9039-54583b804f41',
#   'unit': {'uid': 'c515b679-57c6-4a56-9039-54583b804f41',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '47b87008-204e-4fdb-b74a-f8b71894c872',
#   'unit': {'uid': '47b87008-204e-4fdb-b74a-f8b71894c872',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0',
#   'unit': {'uid': '4f0e4bab-a2b0-49f5-940c-cffc7fb826c0',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '942a6864-d942-4933-99c4-1bb0295f49f9',
#   'unit': {'uid': '942a6864-d942-4933-99c4-1bb0295f49f9',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'e8c01e3a-c4ea-414e-8bf7-703ae5157714',
#   'unit': {'uid': 'e8c01e3a-c4ea-414e-8bf7-703ae5157714',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '8e638e9b-df13-4bdf-9e7d-2da6ed34a655',
#   'unit': {'uid': '8e638e9b-df13-4bdf-9e7d-2da6ed34a655',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'dbf119b9-8f7a-4f27-9891-7373825423e1',
#   'unit': {'uid': 'dbf119b9-8f7a-4f27-9891-7373825423e1',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#   'unit': {'uid': '4cf815fa-10c3-474a-94e7-6ac6ba01b499',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#   'unit': {'uid': 'eb3b0b53-26f2-465f-9069-b0c6b7df43a1',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#   'unit': {'uid': 'ea9d0fd9-bff6-4437-b40e-6992888a9632',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#   'unit': {'uid': 'f34c1184-9592-498d-af8e-11df1b02e389',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#   'unit': {'uid': '91633631-6a5c-4693-bdd4-c83a20eef913',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#   'unit': {'uid': '91bfdb7f-7392-4237-b357-d723fa893908',
#    'key': 'time',
#    'doc': 'note',
#    'time': '12:02:02_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}},
#  {'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#   'unit': {'uid': 'fc468332-3d1f-4185-a9b9-efd279068c66',
#    'key': 'key',
#    'doc': 'note',
#    'time': '12:02:03_AM',
#    'date': '01_07_2024',
#    'metadata': None,
#    'data_type': 'str'}}]
