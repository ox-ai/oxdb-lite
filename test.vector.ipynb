# %%
from oxdb.ai.embed import VectorModel

# %%
md = VectorModel()

# %%
md.search("hi",data=["lok"*100,"phy"*100,"onnx","ox_onnx"]*100)
# Out:
# {'idx': [23,
#   55,
#   67,
#   63,
#   51,
#   47,
#   59,
#   391,
#   43,
#   39,
#   135,
#   395,
#   3,
#   295,
#   307,
#   343,
#   355,
#   351,
#   299,
#   335,
#   347,
#   383,
#   327,
#   339,
#   127,
#   139,
#   123,
#   119,
#   131,
#   103,
#   115,
#   111,
#   191,
#   107,
#   271,
#   283,
#   279,
#   263,
#   275,
#   323,
#   319,
#   267,
#   303,
#   315,
#   311,
#   187,
#   183,
#   195,
#   167,
#   179,
#   175,
#   223,
#   171,
#   219,
#   215,
#   227,
#   199,
#   211,
#   207,
#   255,
#   203,
#   239,
#   251,
#   247,
#   259,
#   231,
#   243,
#   99,
#   95,
#   235,
#   79,
#   91,
#   87,
#   71,
#   83,
#   291,
#   287,
#   75,
#   19,
#   15,
#   27,
#   159,
#   11,
#   7,
#   155,
#   151,
#   163,
#   331,
#   147,
#   143,
#   375,
#   387,
#   371,
#   367,
#   379,
#   31,
#   363,
#   359,
#   399,
#   35,
#   41,
#   40,
#   37,
#   36,
#   45,
#   44,
#   57,
#   56,
#   361,
#   360,
#   357,
#   356,
#   369,
#   368,
# ...

# %%
md.sim(md.model.encode("hi"),md.model.encode("hi"))
# Out:
# 58268029
